# %%
import soundfile
from scipy import signal
from scipy.fft import fftshift
import matplotlib.pyplot as plt
import numpy as np
from CountWords import CountWords

speechDict = CountWords("data/LibriSpeech/dev-clean/84/121123/84-121123.trans.txt")
print("Number of words:{}".format(speechDict[0]["count"]))

x, fs = soundfile.read("data/LibriSpeech/dev-clean/84/121123/84-121123-0000.flac")

t = np.linspace(0,10,num=len(x))

plt.plot(t,x)
plt.show()
# Out:
# Number of words:4

# %%
f, t, Sxx = signal.spectrogram(x, fs)

plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
